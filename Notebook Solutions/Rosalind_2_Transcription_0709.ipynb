# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolcevice/Rosalind-Answers/blob/master/Rosalind_2_Transcription_0709.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
target = input("Enter: ")
DNA_to_RNA = {'T' : 'U'}
result = ''

for ch in target:
  try:
    result += DNA_to_RNA.get(ch)
  except:
    result += ch
    
print (result)
# Out:
# Enter: ...
# ...
